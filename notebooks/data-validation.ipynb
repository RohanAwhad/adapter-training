# %%
import json

train_data_path = './data/generated/adapter_train.jsonl'

train_data = []
with open(train_data_path, 'r') as f:
    for line in f: train_data.append(json.loads(line))

train_data[0]
# Out:
# {'messages': [{'role': 'system',
# ...

# %%
train_data[1]['messages']
# Out:
# [{'role': 'system',
# ...

# %%
# manual SDG output

import pandas as pd

df = pd.read_pickle('./data/full_df_deduped.pkl')

df.head()
# Out:
#                             source_dataset source_config  source_row_idx  \
# 0  NousResearch/hermes-function-calling-v1  func_calling             977
# 1  NousResearch/hermes-function-calling-v1  func_calling            1587
# 2  NousResearch/hermes-function-calling-v1  func_calling            1360
# 3  NousResearch/hermes-function-calling-v1  func_calling            1738
# 4  NousResearch/hermes-function-calling-v1  func_calling            1347
#
#                                      id  \
# 0  2e583020-ea45-4496-aafe-a6d141ed1ad7
# 1  99abd602-3854-41e1-9fe7-31dcef70ad39
# 2  beb07363-1986-4701-a4b7-27e04536f093
# 3  28558c88-cfd6-431e-894a-3d7510b416ba
# 4  248b82c3-e473-40e8-91ff-74d9b314cd1f
#
#                                        conversations  \
# 0  [{'from': 'system', 'value': 'You are a functi...
# 1  [{'from': 'system', 'value': 'You are an exper...
# 2  [{'from': 'system', 'value': 'You are an exper...
# 3  [{'from': 'system', 'value': 'You are an exper...
# ...
